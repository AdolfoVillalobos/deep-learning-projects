# %%
import tensorflow as tf

# %%
sentences = [
    "I love my cat",
    "i, love my dog",
    "You, love my dog!",
    "Do you think my dog is amazing?"
]

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=100, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'<OOV>': 1, 'my': 2, 'love': 3, 'dog': 4, 'i': 5, 'you': 6, 'cat': 7, 'do': 8, 'think': 9, 'is': 10, 'amazing': 11}

# %%
sequences = tokenizer.texts_to_sequences(sentences)

padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(sequences, padding="post")

# %%
padded_sequences
# Out:
# array([[ 0,  0,  0,  5,  3,  2,  7],
#        [ 0,  0,  0,  5,  3,  2,  4],
#        [ 0,  0,  0,  6,  3,  2,  4],
#        [ 8,  6,  9,  2,  4, 10, 11]], dtype=int32)

# %%
test_sentences = [
    "I love my sister"
]

# %%
tokenizer.texts_to_sequences(test_sentences)
# Out:
# [[5, 3, 2, 1]]

# %% [markdown]
# The word "sister" is not in the vocabulary, and hence is omited
