# %% [markdown]
# # Word Embeddings

# %%
import io
import os
import re
import shutil
import string
import tensorflow as tf

from datetime import datetime
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# %load_ext tensorboard

# %% [markdown]
# ## Download Data

# %%
url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file("aclImdb_v1.tar.gz", url,
                                    untar=True, cache_dir='.',
                                    cache_subdir='')
dataset_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')
os.listdir(dataset_dir)
# Out:
# Downloading data from https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# 84131840/84125825 [==============================] - 50s 1us/step
# ['imdbEr.txt', 'test', 'imdb.vocab', 'README', 'train']

# %%
train_dir = os.path.join(dataset_dir, "train")
os.listdir(train_dir)
# Out:
# ['urls_unsup.txt',
#  'neg',
#  'urls_pos.txt',
#  'unsup',
#  'urls_neg.txt',
#  'pos',
#  'unsupBow.feat',
#  'labeledBow.feat']

# %%
remove_dir = os.path.join(train_dir, "unsup")
shutil.rmtree(remove_dir)

# %% [markdown]
# ## Load Dataset

# %%
batch_size = 1024
seed = 123

# %%
train_ds = tf.keras.preprocessing.text_dataset_from_directory(
            "aclImdb/train", batch_size=batch_size, validation_split=0.2,
            subset="training", seed=seed)

val_ds = tf.keras.preprocessing.text_dataset_from_directory("aclImdb/train",
                                                           batch_size=batch_size, validation_split=0.2,
                                                           subset="validation", seed=seed)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %%
for text_batch, label_batch in train_ds.take(1):
    for i in range(5):
        print(label_batch[i].numpy(), text_batch.numpy()[i], end='\n')
        print(" ")
# Out:
# 1 b"The original animated Dark Knight returns in this ace adventure movie that rivals Mask of Phantasm in its coolness. There's a lot of style and intelligence in Mystery of the Batwoman, so much more than Batman Forever or Batman and Robin.<br /><br />There's a new crime-fighter on the streets of Gotham. She dresses like a bat but she's not a grown-up Batgirl. And Batman is denying any affiliation with her. Meanwhile Bruce Wayne has to deal with the usual romances and detective work. But the Penguin, Bain and the local Mob makes things little more complicated.<br /><br />I didn't have high hopes for this 'un since being strongly let down but the weak Batman: Sub Zero (Robin isn't featured so much here!)but I was delighted with the imaginative and exciting set pieces, the clever plot and a cheeky sense of humor. This is definitely a movie no fan of Batman should be without. Keep your ears open for a really catchy song called 'Betcha Neva' which is featured prominently through-out.<br /><br />It's a shame the DVD isn't so great. Don't get me wrong there are some great features (the short 'Chase Me' is awesome) and a very cool Dolby 5.1 soundtrack but... the movie is presented in Pan and Scan. Batman: Mystery of the Batwoman was drawn and shot in 1.85:1 but this DVD is presented in 1.33:1 an in comparison to the widescreen clips shown on the features there IS picture cut off on both sides. I find this extremely annoying considering Mask of Phantasm was presented in anamorphic widescreen. Warner have had to re-release literally dozens of movies on DVD because people have complained about the lack of Original Aspect Ratio available on some titles. Why they chose to make that same mistake here again is beyond me.<br /><br />I would give this DVD 5/5 but the lack of OAR brings the overall score down to 4/5. It's a shame because widescreen would have completed a great DVD package."
#
# 1 b'Probably my all-time favorite movie, a story of selflessness, sacrifice and dedication to a noble cause, but it\'s not preachy or boring. It just never gets old, despite my having seen it some 15 or more times in the last 25 years. Paul Lukas\' performance brings tears to my eyes, and Bette Davis, in one of her very few truly sympathetic roles, is a delight. The kids are, as grandma says, more like "dressed-up midgets" than children, but that only makes them more fun to watch. And the mother\'s slow awakening to what\'s happening in the world and under her own roof is believable and startling. If I had a dozen thumbs, they\'d all be "up" for this movie.'
#
# 1 b'I claim no matter how hard I seek I\'ll never find a better movie version of "Othello". If you love Kenneth Branagh\'s magnificent masterpieces "Much ado about nothing" (1993) and "Hamlet" (1996) as much as I do I\'m dead certain you\'ll also find Oliver Parker\'s "Othello" irresistible. Laurence Fishburne has been in a various splendid roles during his career. He was quite terrific in "Boys n the hood" (1991) - I\'ve always considered his amusing role of Furious Styles as his very greatest achievement. That was, of course, way before I saw this.<br /><br />He plays the part of Othello and he is probably in the most challenging role of his whole career but he does a brilliant, fantastic job. Ir\xc3\xa8ne Jacob is absolutely charming Desdemona and Kenneth Branagh is just simply phenomenal in a most fascinating role of the story\'s crooked, manipulate villain Iago. Marvelous "Othello" is part of the absolute elite among Shakespeare\'s ingenious works. It deals with his favorite topics: crookedness, envy, deceitfulness and jealousy. This movie adaptation is certainly one of the finest films I\'ve seen that\'s based on William Shakespeare\'s plays.'
#
# 1 b"Some people say this is the best film that PRC ever released, I'm not too sure about that since I have a fond place in my heart for some of their mysteries. I will say that this is probably one of the most unique films they, or any other studio, major or minor, ever released.<br /><br />The plot is simple. The ghost of a wrongly executed ferryman has returned to the swamp to kill all those who lynched him as well as all of their off spring. Into this mix comes the granddaughter of one ghosts victims, the current ferryman. She takes over the ferry business as the ghost closes in on the man she loves.<br /><br />Shrouded in dense fog and set primarily on the single swamp set this is more musical poem than regular feature film.Listen to the rhythms of the dialog, especially in the early scenes, their is poetical cadence to them. Likewise there is a similar cadence to the camera work as it travels back and forth across the swamp as if crossing back and forth across the door way between life and death, innocence and guilt. The film reminds me of an opera or oratorio or musical object lesson more than a normal horror film. Its an amazing piece of film making that is probably unique in film history.<br /><br />This isn't to guild the Lilly. This is a low budget horror/mystery that tells you a neat little story that will keep you entertained. Its tale of love and revenge is what matters here, not the poetical film making and it holds you attention first and foremost (the technical aspects just being window dressing.) If there is any real flaw its the cheapness of the production. The fog does create a mood but it also hides the fact that this swamp is entirely on dry land. The constant back and forth across it is okay for a while but even after 58 minutes you do wish that we could see something else.<br /><br />Don't get me wrong I do like the film a great deal. Its a good little film that I some how wish was slightly less poverty stricken. Its definitely worth a look if you can come across it."
#
# 1 b'A journey of discovery, this film follows the lives of one family living in a sleepy, island town in British Columbia. Languorous and dreamy, the inhabitants are satisfied to allow life to go on around them until a young, fresh-faced teacher, with new ideas arrives and brings with her life from the mainland. Slowly, their indolent state is awakened, the father (and principal of the local school) looks for excitement, the mother for stability, the oldest daughter for love, and the youngest for power. While not an incredible or ground-breaking piece of cinema, the movie is quietly enjoyable and good for a tired night when the wind is blowing. Unfortunately, I doubt anyone outside of Canada will find it easily accessible.'

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Embedding Layer Example

# %%
embedding_layer = tf.keras.layers. Embedding(1000, 5)

# %%
result = embedding_layer(tf.constant([1,2,3]))
result.numpy()
# Out:
# array([[-0.02723383, -0.04862229, -0.03262519,  0.03796724, -0.01996624],
#        [ 0.02354953, -0.0430707 , -0.01734068,  0.00312878, -0.02443675],
#        [ 0.00325755, -0.0085156 , -0.04519049,  0.00444851, -0.00714653]],
#       dtype=float32)

# %%
result = embedding_layer(tf.constant([[0,1,2],[3,4,5]]))
result.shape
# Out:
# TensorShape([2, 3, 5])

# %% [markdown]
# ## Text Preprocessing
#
# Here we tokenize the text dataset.

# %%
def custom_standarization(input_data):
    
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, ' <br />', '')
    return tf.strings.regex_replace(stripped_html, '[%s]'%re.escape(string.punctuation), '')

# %%
vocab_size = 10000
sequence_length = 100

# %%
vectorize_layer = TextVectorization(standardize=custom_standarization,
                                   max_tokens=vocab_size, output_mode="int",
                                   output_sequence_length=sequence_length)

text_ds = train_ds.map(lambda x, y: x)
vectorize_layer.adapt(text_ds)

# %%
vectorize_layer.get_vocabulary()
# Out:
# ['',
#  '[UNK]',
#  'the',
#  'and',
#  'a',
#  'of',
#  'to',
#  'is',
#  'in',
#  'it',
#  'i',
#  'this',
#  'that',
#  'was',
#  'as',
#  'br',
#  'with',
#  'for',
#  'movie',
#  'but',
#  'film',
#  'on',
#  'not',
#  'you',
#  'are',
#  'his',
#  'have',
#  'be',
#  'he',
#  'one',
#  'its',
#  'at',
#  'all',
#  'by',
#  'an',
#  'they',
#  'who',
#  'from',
#  'so',
#  'like',
#  'her',
#  'just',
#  'or',
#  'about',
#  'has',
#  'if',
#  'out',
#  'some',
#  'there',
#  'what',
#  'good',
#  'when',
#  'more',
#  'very',
#  'even',
#  'she',
#  'my',
#  'up',
#  'no',
#  'would',
#  'only',
#  'which',
#  'time',
#  'really',
#  'story',
#  'their',
#  'see',
#  'were',
#  'had',
#  'can',
#  'me',
#  'we',
#  'than',
#  'much',
#  'well',
#  'been',
#  'will',
#  'get',
#  'also',
#  'people',
#  'into',
#  'other',
#  'do',
#  'first',
#  'bad',
#  'great',
#  'because',
#  'how',
#  'most',
#  'him',
#  'dont',
#  'made',
#  'then',
#  'movies',
#  'make',
#  'could',
#  'way',
#  'films',
#  'any',
#  'them',
#  'after',
#  'too',
#  'characters',
#  'think',
#  'watch',
#  'being',
#  'two',
#  'many',
#  'seen',
#  'character',
#  'never',
#  'little',
#  'where',
#  'plot',
#  'acting',
#  'best',
#  'did',
#  'love',
#  'know',
#  'does',
#  'life',
#  'show',
#  'ever',
#  'your',
#  'over',
#  'still',
#  'better',
#  'off',
#  'these',
#  'end',
#  'say',
#  'man',
#  'why',
#  'scene',
#  'while',
#  'here',
#  'scenes',
#  'such',
#  'go',
#  'should',
#  'something',
#  'through',
#  'im',
#  'back',
#  'those',
#  'real',
#  'doesnt',
#  'watching',
#  'years',
#  'now',
#  'though',
#  'thing',
#  'another',
#  'didnt',
#  'actors',
#  'actually',
#  'new',
#  'before',
#  'nothing',
#  'makes',
#  'find',
#  'funny',
#  'look',
#  'going',
#  'old',
#  'same',
#  'work',
#  'few',
#  'part',
#  'every',
#  'lot',
#  'us',
#  'director',
#  'again',
#  'want',
#  'cast',
#  'thats',
#  'cant',
#  'quite',
#  'seems',
#  'young',
#  'pretty',
#  'things',
#  'around',
#  'got',
#  'however',
#  'fact',
#  'world',
#  'down',
#  'take',
#  'enough',
#  'both',
#  'give',
#  'between',
#  'own',
#  'may',
#  'thought',
#  'horror',
#  'original',
#  'ive',
#  'big',
#  'always',
#  'series',
#  'without',
#  'gets',
#  'isnt',
#  'almost',
#  'right',
#  'long',
#  'saw',
#  'theres',
#  'point',
#  'role',
#  'action',
#  'come',
#  'interesting',
#  'whole',
#  'least',
#  'times',
#  'must',
#  'bit',
#  'done',
#  'comedy',
#  'might',
#  'family',
#  'guy',
#  'hes',
#  'last',
#  'music',
#  'anything',
#  'minutes',
#  'far',
#  'script',
#  'since',
#  'feel',
#  'probably',
#  'performance',
#  'am',
#  'sure',
#  'kind',
#  'yet',
#  'rather',
#  'away',
#  'worst',
#  'woman',
#  'played',
#  'tv',
#  'girl',
#  'making',
#  'fun',
#  'anyone',
#  'found',
#  'each',
#  'having',
#  'comes',
#  'our',
#  'believe',
#  'course',
#  'although',
#  'trying',
#  'goes',
#  'looks',
#  'shows',
#  'especially',
#  'day',
#  'put',
#  'hard',
#  'wasnt',
#  'place',
#  'different',
#  'maybe',
#  'once',
#  'sense',
#  'worth',
#  'main',
#  'set',
#  'true',
#  'reason',
#  'looking',
#  'watched',
#  'someone',
#  'money',
#  'ending',
#  'job',
#  'said',
#  'everything',
#  'takes',
#  'book',
#  'dvd',
#  'during',
#  'plays',
#  'screen',
#  'three',
#  'actor',
#  'later',
#  'play',
#  'seem',
#  'instead',
#  '2',
#  'effects',
#  'everyone',
#  'together',
#  'audience',
#  'version',
#  'seeing',
#  'himself',
#  '10',
#  'left',
#  'night',
#  'special',
#  'john',
#  'beautiful',
#  'american',
#  'excellent',
#  'house',
#  'nice',
#  'idea',
#  'simply',
#  'youre',
#  'shot',
#  'high',
#  'black',
#  'kids',
#  'wife',
#  'read',
#  'less',
#  'fan',
#  'completely',
#  'help',
#  'second',
#  'war',
#  'else',
#  'star',
#  'used',
#  'year',
#  'try',
#  'rest',
#  'poor',
#  'use',
#  'need',
#  'friends',
#  'given',
#  'men',
#  'death',
#  'classic',
#  'home',
#  'until',
#  'performances',
#  'mind',
#  'short',
#  'hollywood',
#  'enjoy',
#  'half',
#  'father',
#  'either',
#  'along',
#  'truly',
#  'women',
#  'wrong',
#  'tell',
#  'next',
#  'dead',
#  'boring',
#  'came',
#  'line',
#  'couple',
#  'remember',
#  'start',
#  'wonderful',
#  'production',
#  'recommend',
#  'getting',
#  'full',
#  'mean',
#  'let',
#  'perhaps',
#  'understand',
#  'playing',
#  'terrible',
#  'gives',
#  'face',
#  'definitely',
#  'awful',
#  'stupid',
#  'others',
#  'doing',
#  'camera',
#  'often',
#  'keep',
#  'small',
#  'sex',
#  'moments',
#  'early',
#  'become',
#  'video',
#  'episode',
#  'name',
#  'dialogue',
#  'school',
#  'supposed',
#  'perfect',
#  'person',
#  'itself',
#  'human',
#  'liked',
#  'sort',
#  'top',
#  'lost',
#  'lines',
#  'finally',
#  'felt',
#  'yes',
#  'entire',
#  'couldnt',
#  'went',
#  'stars',
#  'title',
#  'piece',
#  'evil',
#  'absolutely',
#  'case',
#  'problem',
#  'live',
#  'hope',
#  'against',
#  'shes',
#  'waste',
#  'written',
#  'budget',
#  'certainly',
#  'loved',
#  'fans',
#  'white',
#  'several',
#  'style',
#  'head',
#  'picture',
#  'cinema',
#  'based',
#  'overall',
#  'becomes',
#  'worse',
#  'id',
#  'oh',
#  'killer',
#  'example',
#  'direction',
#  'seemed',
#  'entertaining',
#  'beginning',
#  'boy',
#  'mr',
#  'mother',
#  'guys',
#  '\x96',
#  'dark',
#  'unfortunately',
#  'turn',
#  'care',
#  '3',
#  'despite',
#  'final',
#  'throughout',
#  'already',
#  'wanted',
#  'drama',
#  'amazing',
#  'lives',
#  'laugh',
#  'low',
#  'tries',
#  'wont',
#  'friend',
#  'fine',
#  'children',
#  'youll',
#  'totally',
#  'sound',
#  'under',
#  'lead',
#  'works',
#  'history',
#  'guess',
#  '1',
#  'girls',
#  'writing',
#  'theyre',
#  'wants',
#  'called',
#  'able',
#  'turns',
#  'humor',
#  'act',
#  'favorite',
#  'starts',
#  'behind',
#  'past',
#  'michael',
#  'enjoyed',
#  'gave',
#  'quality',
#  'sometimes',
#  'kill',
#  'days',
#  'child',
#  'soon',
#  'viewer',
#  'side',
#  'game',
#  'parts',
#  'son',
#  'flick',
#  'town',
#  'themselves',
#  'car',
#  'thinking',
#  'genre',
#  'ones',
#  'itbr',
#  'eyes',
#  'directed',
#  'heart',
#  'expect',
#  'obviously',
#  'decent',
#  'ill',
#  'feeling',
#  'brilliant',
#  'art',
#  'says',
#  'horrible',
#  'stories',
#  'late',
#  'actress',
#  'fight',
#  'close',
#  'highly',
#  'cannot',
#  'killed',
#  'happens',
#  'stuff',
#  'heard',
#  'took',
#  'run',
#  'moment',
#  'particularly',
#  'blood',
#  'leave',
#  'myself',
#  'wouldnt',
#  'hour',
#  'extremely',
#  'city',
#  'except',
#  'wonder',
#  'matter',
#  'kid',
#  'hand',
#  'attempt',
#  'roles',
#  'hell',
#  'happened',
#  'etc',
#  'strong',
#  'police',
#  'involved',
#  'obvious',
#  'lack',
#  'complete',
#  'anyway',
#  'told',
#  'james',
#  'chance',
#  'group',
#  'including',
#  'coming',
#  'voice',
#  'type',
#  'violence',
#  'daughter',
#  'living',
#  'looked',
#  'please',
#  'happen',
#  'save',
#  'number',
#  'murder',
#  'alone',
#  'shown',
#  'lets',
#  'usually',
#  'score',
#  'age',
#  'ok',
#  'stop',
#  'god',
#  'taken',
#  'simple',
#  'none',
#  'slow',
#  'interest',
#  'ago',
#  'moviebr',
#  'experience',
#  'exactly',
#  'yourself',
#  'mostly',
#  'david',
#  'ends',
#  'usual',
#  'opening',
#  'cinematography',
#  'career',
#  'annoying',
#  'whose',
#  'across',
#  'known',
#  'finds',
#  'song',
#  'started',
#  'huge',
#  'hilarious',
#  'sad',
#  'relationship',
#  'hit',
#  'scary',
#  'musical',
#  'serious',
#  'released',
#  'hours',
#  'episodes',
#  'english',
#  'cut',
#  'robert',
#  'possible',
#  'brother',
#  'wish',
#  'somewhat',
#  'seriously',
#  'shots',
#  'major',
#  'running',
#  'order',
#  'cool',
#  'change',
#  'taking',
#  'jokes',
#  'female',
#  'hero',
#  'body',
#  'saying',
#  'gore',
#  'reality',
#  'opinion',
#  '4',
#  'events',
#  'crap',
#  'view',
#  'knew',
#  'call',
#  'ridiculous',
#  'directors',
#  'strange',
#  'talking',
#  '5',
#  'turned',
#  'today',
#  'knows',
#  'supporting',
#  'power',
#  'king',
#  'happy',
#  'basically',
#  'arent',
#  'level',
#  'apparently',
#  'due',
#  'local',
#  'filmbr',
#  'clearly',
#  'attention',
#  'tells',
#  'sequence',
#  'novel',
#  'easily',
#  'room',
#  'documentary',
#  'rating',
#  'appears',
#  'modern',
#  'british',
#  'songs',
#  'falls',
#  'husband',
#  'words',
#  'sets',
#  'whether',
#  'talent',
#  'bring',
#  'important',
#  'whats',
#  'future',
#  'beyond',
#  'country',
#  'problems',
#  'four',
#  'cheap',
#  'single',
#  'word',
#  'viewers',
#  'predictable',
#  'similar',
#  'needs',
#  'comic',
#  'romantic',
#  'giving',
#  'add',
#  'miss',
#  'light',
#  'jack',
#  'television',
#  'five',
#  'silly',
#  'havent',
#  'actual',
#  'review',
#  'within',
#  'disappointed',
#  'mention',
#  'talk',
#  'upon',
#  'earth',
#  'animation',
#  'lots',
#  'george',
#  'feels',
#  'entertainment',
#  'nearly',
#  'enjoyable',
#  'bunch',
#  'begins',
#  'storyline',
#  'lady',
#  'using',
#  'paul',
#  'herself',
#  'named',
#  'moving',
#  'sorry',
#  'sequel',
#  'surprised',
#  'points',
#  'above',
#  'rock',
#  'richard',
#  'message',
#  'ways',
#  'comments',
#  'theme',
#  'showing',
#  'stay',
#  'ten',
#  'dull',
#  'dialog',
#  'team',
#  'typical',
#  'thriller',
#  'somehow',
#  'avoid',
#  'middle',
#  'fall',
#  'theater',
#  'mystery',
#  'fantastic',
#  'doubt',
#  'parents',
#  'release',
#  'leads',
#  'easy',
#  'writer',
#  'york',
#  'near',
#  'kept',
#  'certain',
#  'among',
#  'tried',
#  'hate',
#  'famous',
#  'weak',
#  'means',
#  'elements',
#  'effort',
#  'tale',
#  'sister',
#  'learn',
#  'working',
#  'feature',
#  'general',
#  'viewing',
#  'straight',
#  'particular',
#  'soundtrack',
#  'filmed',
#  'brought',
#  'greatest',
#  'figure',
#  'clear',
#  'class',
#  'gone',
#  'eventually',
#  'editing',
#  'buy',
#  'realistic',
#  'fast',
#  'hear',
#  'eye',
#  'de',
#  'form',
#  'dance',
#  'red',
#  'sequences',
#  'season',
#  'french',
#  'zombie',
#  'youve',
#  'imagine',
#  'check',
#  'oscar',
#  'material',
#  'follow',
#  'move',
#  'whos',
#  'decided',
#  'reviews',
#  'tom',
#  'atmosphere',
#  'space',
#  'forget',
#  'deal',
#  'lame',
#  'became',
#  'wait',
#  'sit',
#  'third',
#  'stand',
#  'expected',
#  'peter',
#  'whatever',
#  'period',
#  'poorly',
#  'possibly',
#  'meets',
#  'difficult',
#  'die',
#  'okay',
#  'truth',
#  'lee',
#  'surprise',
#  'nature',
#  'killing',
#  'indeed',
#  'note',
#  'nor',
#  'leaves',
#  'writers',
#  'subject',
#  'premise',
#  'japanese',
#  'filmmakers',
#  'rent',
#  'stage',
#  'screenplay',
#  'believable',
#  'sexual',
#  'romance',
#  'reading',
#  'question',
#  'needed',
#  'average',
#  'write',
#  'memorable',
#  'suspense',
#  'keeps',
#  'superb',
#  'interested',
#  'dr',
#  'crime',
#  '80s',
#  'meet',
#  'dramatic',
#  'older',
#  'street',
#  'unless',
#  'forced',
#  'boys',
#  'begin',
#  'emotional',
#  'realize',
#  'previous',
#  'features',
#  'disney',
#  'total',
#  'joe',
#  'whom',
#  'minute',
#  'footage',
#  'otherwise',
#  'result',
#  'badly',
#  'situation',
#  'earlier',
#  'baby',
#  'society',
#  'personal',
#  'crazy',
#  'towards',
#  'comment',
#  'incredibly',
#  'brings',
#  'male',
#  'directing',
#  'ask',
#  'hot',
#  'cheesy',
#  'weird',
#  'sounds',
#  'dog',
#  'credits',
#  'appear',
#  'twist',
#  'shame',
#  'beauty',
#  'hands',
#  'development',
#  'creepy',
#  'return',
#  'leading',
#  'effect',
#  'apart',
#  'secret',
#  'fairly',
#  'b',
#  'remake',
#  'plenty',
#  'portrayed',
#  'open',
#  'imdb',
#  'background',
#  'unique',
#  'scifi',
#  'plus',
#  'america',
#  'perfectly',
#  'meant',
#  'hardly',
#  'deep',
#  'admit',
#  '70s',
#  '20',
#  'worked',
#  'quickly',
#  'ideas',
#  'mark',
#  'laughs',
#  'casting',
#  'gay',
#  'powerful',
#  'la',
#  'free',
#  'forward',
#  'mess',
#  'unlike',
#  'christmas',
#  'attempts',
#  'create',
#  'missing',
#  'expecting',
#  'business',
#  'various',
#  'present',
#  'nudity',
#  'setting',
#  'rich',
#  'fantasy',
#  'battle',
#  'inside',
#  'dumb',
#  'brothers',
#  'potential',
#  'fails',
#  'dream',
#  'fire',
#  'recently',
#  'political',
#  'pay',
#  'western',
#  'break',
#  'fighting',
#  'outside',
#  'manages',
#  ...]

# %% [markdown]
# ## Classification Model

# %% [markdown]
# A simple sequential model in Keras.

# %%
embedding_dim = 16
model = Sequential([
    vectorize_layer,
    Embedding(vocab_size, embedding_dim, name="embedding"),
    GlobalAveragePooling1D(),
    Dense(16, activation="relu"),
    Dense(1)
])

# %% [markdown]
# ## Compile and Train The Model

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="logs")

# %%
model.compile(optimizer="adam", loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
             metrics=["accuracy"])

# %%
model.fit(train_ds,
         validation_data=val_ds,
         epochs=25,
         callbacks=[tensorboard_callback])
# Out:
# Epoch 1/25
# 20/20 [==============================] - 6s 305ms/step - loss: 0.6917 - accuracy: 0.5028 - val_loss: 0.6894 - val_accuracy: 0.4886
# Epoch 2/25
# 20/20 [==============================] - 4s 188ms/step - loss: 0.6866 - accuracy: 0.5028 - val_loss: 0.6827 - val_accuracy: 0.4886
# Epoch 3/25
# 20/20 [==============================] - 3s 136ms/step - loss: 0.6776 - accuracy: 0.5028 - val_loss: 0.6714 - val_accuracy: 0.4886
# Epoch 4/25
# 20/20 [==============================] - 2s 111ms/step - loss: 0.6629 - accuracy: 0.5028 - val_loss: 0.6542 - val_accuracy: 0.4886
# Epoch 5/25
# 20/20 [==============================] - 2s 111ms/step - loss: 0.6414 - accuracy: 0.5090 - val_loss: 0.6310 - val_accuracy: 0.5118
# Epoch 6/25
# 20/20 [==============================] - 2s 116ms/step - loss: 0.6137 - accuracy: 0.5699 - val_loss: 0.6035 - val_accuracy: 0.5844
# Epoch 7/25
# 20/20 [==============================] - 2s 112ms/step - loss: 0.5815 - accuracy: 0.6450 - val_loss: 0.5734 - val_accuracy: 0.6540
# Epoch 8/25
# 20/20 [==============================] - 2s 111ms/step - loss: 0.5466 - accuracy: 0.7065 - val_loss: 0.5430 - val_accuracy: 0.7044
# Epoch 9/25
# 20/20 [==============================] - 3s 132ms/step - loss: 0.5117 - accuracy: 0.7519 - val_loss: 0.5148 - val_accuracy: 0.7312
# Epoch 10/25
# 20/20 [==============================] - 2s 119ms/step - loss: 0.4788 - accuracy: 0.7832 - val_loss: 0.4910 - val_accuracy: 0.7390
# Epoch 11/25
# 20/20 [==============================] - 2s 119ms/step - loss: 0.4496 - accuracy: 0.7983 - val_loss: 0.4694 - val_accuracy: 0.7530
# Epoch 12/25
# 20/20 [==============================] - 3s 137ms/step - loss: 0.4229 - accuracy: 0.8128 - val_loss: 0.4503 - val_accuracy: 0.7740
# Epoch 13/25
# 20/20 [==============================] - 3s 130ms/step - loss: 0.3996 - accuracy: 0.8249 - val_loss: 0.4349 - val_accuracy: 0.7858
# Epoch 14/25
# 20/20 [==============================] - 3s 151ms/step - loss: 0.3791 - accuracy: 0.8375 - val_loss: 0.4230 - val_accuracy: 0.7868
# Epoch 15/25
# 20/20 [==============================] - 3s 145ms/step - loss: 0.3610 - accuracy: 0.8445 - val_loss: 0.4133 - val_accuracy: 0.7922
# Epoch 16/25
# 20/20 [==============================] - 3s 156ms/step - loss: 0.3446 - accuracy: 0.8515 - val_loss: 0.4052 - val_accuracy: 0.7986
# Epoch 17/25
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3300 - accuracy: 0.8594 - val_loss: 0.3991 - val_accuracy: 0.7996
# Epoch 18/25
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3166 - accuracy: 0.8665 - val_loss: 0.3942 - val_accuracy: 0.8008
# Epoch 19/25
# 20/20 [==============================] - 2s 114ms/step - loss: 0.3044 - accuracy: 0.8731 - val_loss: 0.3889 - val_accuracy: 0.8066
# Epoch 20/25
# 20/20 [==============================] - 2s 116ms/step - loss: 0.2931 - accuracy: 0.8770 - val_loss: 0.3848 - val_accuracy: 0.8156
# Epoch 21/25
# 20/20 [==============================] - 3s 133ms/step - loss: 0.2827 - accuracy: 0.8830 - val_loss: 0.3839 - val_accuracy: 0.8110
# Epoch 22/25
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2733 - accuracy: 0.8867 - val_loss: 0.3824 - val_accuracy: 0.8118
# Epoch 23/25
# 20/20 [==============================] - 3s 140ms/step - loss: 0.2644 - accuracy: 0.8918 - val_loss: 0.3806 - val_accuracy: 0.8144
# Epoch 24/25
# 20/20 [==============================] - 2s 114ms/step - loss: 0.2556 - accuracy: 0.8967 - val_loss: 0.3824 - val_accuracy: 0.8090
# Epoch 25/25
# 20/20 [==============================] - 2s 115ms/step - loss: 0.2492 - accuracy: 0.8976 - val_loss: 0.3826 - val_accuracy: 0.8112

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_vectorization (TextVect (None, 100)               0
# _________________________________________________________________
# embedding (Embedding)        (None, 100, 16)           160000
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Retreive and save the model

# %%
weights = model.get_layer("embedding").get_weights()[0]
vocab = vectorize_layer.get_vocabulary()

# %%
out_v = io.open("vectors.tsv", "w", encoding ="utf-8")
out_m = io.open("metadata.tsv", "w", encoding="utf-8")

for index, word in enumerate(vocab):
    if index==0:
        continue # Padding
    
    vec = weights[index]
    out_v.write("\t".join([str(x) for x in vec])+"\n")
    out_m.write(word+"\n")
out_v.close()
out_m.close()

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 96963), started 0:12:44 ago. (Use '!kill 96963' to kill it.)
#       <iframe id="tensorboard-frame-705fc30fbcaa4a5c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-705fc30fbcaa4a5c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
